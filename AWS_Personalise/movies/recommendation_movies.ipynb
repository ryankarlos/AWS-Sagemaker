# %% [markdown]
# ### Recommendation Algos Demo - Ryan

# %%
import pandas as pd
import numpy as np
import sklearn
from zipfile import ZipFile
from dask import dataframe as dd 
from surprise import SVD, Dataset, Reader
from surprise.model_selection import cross_validate
from collections import defaultdict
from surprise import KNNBaseline
from pyspark.sql import SQLContext, SparkSession
from pyspark.ml.recommendation import ALS
from pyspark import SparkContext, SparkConf
import implicit
import boto3
from sklearn.utils import shuffle
# %load_ext line_profiler
#zip = ZipFile('data/ml-latest-small.zip')
#zip.extractall()

# %%
df_dict = {}
for name in {'links', 'movies', 'ratings', 'tags'}:
    df_dict[f'{name}'] = pd.read_csv(f'data/ml-latest-small/{name}.csv')
    
movies_df = df_dict['movies']
links_df = df_dict['links']
ratings_df = df_dict['ratings']
tags_df = df_dict['tags']

# %% [markdown]
# ### MovieLens Dataset
#
# https://grouplens.org/datasets/movielens/

# %%
movies_df.set_index('movieId')
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# 193581               Action|Animation|Comedy|Fantasy
# 193583                      Animation|Comedy|Fantasy
# 193585                                         Drama
# 193587                              Action|Animation
# 193609                                        Comedy
#
# [9742 rows x 2 columns]

# %%
ratings_df.head(7)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868

# %%
df_merged = movies_df.merge(ratings_df, on='movieId').merge(links_df, on="movieId")
input_df_model =  df_merged.loc[:, ['userId', 'movieId', 'rating', 'title']]

movie_id_name_df = input_df_model.loc[:, ['title', 'movieId']].drop_duplicates()
keys = movie_id_name_df['movieId']
values = movie_id_name_df['title']

id_to_title_map = {key:value for key, value in zip(keys, values)}
title_to_id_map = {value:key for key, value in zip(keys, values)}
    
#dict(sorted(movie_id_name_df.values.tolist()))

# %% [markdown]
# ### SVD

# %%
def get_top_n(predictions, n=10):
    '''Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    '''

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
# A reader is still needed but only the rating_scale param is requiered.
reader = Reader(rating_scale=(1, 5))

# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(input_df_model[['userId', 'movieId', 'rating']], reader)
trainset = data.build_full_trainset()

algo = SVD()
algo.fit(trainset)

# Than predict ratings for all pairs (u, i) that are NOT in the training set.
testset = trainset.build_anti_testset()
predictions = algo.test(testset)

# %%
top_n = get_top_n(predictions, n=5)

# Print the recommended items for each user
for uid, user_ratings in top_n.items():
    print(f'Recommendations for User {uid}:', eval(str([id_to_title_map[iid] for (iid, _) in user_ratings])), '\n\n')
# Out:
# Recommendations for User 1: ['Shawshank Redemption, The (1994)', 'In the Name of the Father (1993)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Godfather, The (1972)']
#
#
# Recommendations for User 5: ['Notorious (1946)', 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)', 'Boogie Nights (1997)', 'North by Northwest (1959)', 'Evil Dead II (Dead by Dawn) (1987)']
#
#
# Recommendations for User 7: ['North by Northwest (1959)', 'Rear Window (1954)', 'Streetcar Named Desire, A (1951)', 'Dark Knight, The (2008)', 'Last King of Scotland, The (2006)']
#
#
# Recommendations for User 15: ['Goodfellas (1990)', 'Fargo (1996)', 'Lawrence of Arabia (1962)', 'Godfather: Part II, The (1974)', 'Great Escape, The (1963)']
#
#
# Recommendations for User 17: ['Life Is Beautiful (La Vita è bella) (1997)', 'Lawrence of Arabia (1962)', 'Trainspotting (1996)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Boondock Saints, The (2000)']
#
#
# Recommendations for User 18: ['Streetcar Named Desire, A (1951)', 'Lawrence of Arabia (1962)', 'Philadelphia Story, The (1940)', 'Grave of the Fireflies (Hotaru no haka) (1988)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)']
#
#
# Recommendations for User 19: ['Lord of the Rings: The Return of the King, The (2003)', 'Apocalypse Now (1979)', 'Ran (1985)', 'Amadeus (1984)', 'Departed, The (2006)']
#
#
# Recommendations for User 21: ['Go (1999)', "Schindler's List (1993)", 'Fugitive, The (1993)', 'In the Name of the Father (1993)', 'Star Trek II: The Wrath of Khan (1982)']
#
#
# Recommendations for User 27: ["Schindler's List (1993)", 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)', 'Kiss Kiss Bang Bang (2005)', 'Harry Potter and the Goblet of Fire (2005)', 'In Bruges (2008)']
#
#
# Recommendations for User 31: ['Godfather, The (1972)', 'Pulp Fiction (1994)', 'Fight Club (1999)', 'Cool Hand Luke (1967)', 'Boot, Das (Boat, The) (1981)']
#
#
# Recommendations for User 32: ['Fight Club (1999)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Lawrence of Arabia (1962)', 'Lord of the Rings: The Return of the King, The (2003)', 'Life Is Beautiful (La Vita è bella) (1997)']
#
#
# Recommendations for User 33: ['Bridge on the River Kwai, The (1957)', 'Seven Samurai (Shichinin no samurai) (1954)', 'Streetcar Named Desire, A (1951)', 'Patton (1970)', 'Snatch (2000)']
#
#
# Recommendations for User 40: ['Fight Club (1999)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Boondock Saints, The (2000)', 'Brazil (1985)', 'Wallace & Gromit: The Best of Aardman Animation (1996)']
#
#
# Recommendations for User 43: ['Heat (1995)', 'Nixon (1995)', 'Casino (1995)', 'Usual Suspects, The (1995)', 'Postman, The (Postino, Il) (1994)']
#
#
# Recommendations for User 44: ['Amadeus (1984)', 'Sting, The (1973)', 'Great Escape, The (1963)', 'Rebecca (1940)', 'Evil Dead II (Dead by Dawn) (1987)']
#
#
# Recommendations for User 45: ['Shawshank Redemption, The (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'WALL·E (2008)', 'Adaptation (2002)', 'Never Cry Wolf (1983)']
#
#
# Recommendations for User 46: ['Forrest Gump (1994)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Snatch (2000)', 'Great Escape, The (1963)', 'In the Name of the Father (1993)']
#
#
# Recommendations for User 50: ["One Flew Over the Cuckoo's Nest (1975)", 'Godfather: Part II, The (1974)', 'American Beauty (1999)', "Schindler's List (1993)", 'Great Escape, The (1963)']
#
#
# Recommendations for User 54: ['Casablanca (1942)', 'To Kill a Mockingbird (1962)', 'Seven Samurai (Shichinin no samurai) (1954)', 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)', 'Princess Bride, The (1987)']
#
#
# Recommendations for User 57: ['Fight Club (1999)', 'Shawshank Redemption, The (1994)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Memento (2000)', 'Kill Bill: Vol. 1 (2003)']
#
#
# Recommendations for User 63: ['Rear Window (1954)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Toy Story 2 (1999)', "Miller's Crossing (1990)", 'Ran (1985)']
#
#
# Recommendations for User 64: ['Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Philadelphia Story, The (1940)', 'Boondock Saints, The (2000)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Streetcar Named Desire, A (1951)']
#
#
# Recommendations for User 66: ["Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", "Schindler's List (1993)", 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'To Catch a Thief (1955)', 'Boot, Das (Boat, The) (1981)']
#
#
# Recommendations for User 68: ['Outlaw Josey Wales, The (1976)', 'Open Your Eyes (Abre los ojos) (1997)', 'Hunt, The (Jagten) (2012)', 'Dog Day Afternoon (1975)', 'His Girl Friday (1940)']
#
#
# Recommendations for User 71: ['Life Is Beautiful (La Vita è bella) (1997)', 'Dark Knight, The (2008)', 'Green Mile, The (1999)', 'Shawshank Redemption, The (1994)', 'Ran (1985)']
#
#
# Recommendations for User 73: ['Usual Suspects, The (1995)', 'Forrest Gump (1994)', 'North by Northwest (1959)', 'Femme Nikita, La (Nikita) (1990)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)']
#
#
# Recommendations for User 76: ['To Catch a Thief (1955)', 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'WALL·E (2008)', 'Life Is Beautiful (La Vita è bella) (1997)', 'His Girl Friday (1940)']
#
#
# Recommendations for User 78: ['Saving Private Ryan (1998)', 'Hoop Dreams (1994)', 'Donnie Darko (2001)', 'Fight Club (1999)', 'Reservoir Dogs (1992)']
#
#
# Recommendations for User 82: ['Streetcar Named Desire, A (1951)', 'Stand by Me (1986)', 'Life Is Beautiful (La Vita è bella) (1997)', 'Go (1999)', 'Great Escape, The (1963)']
#
#
# Recommendations for User 86: ['Whiplash (2014)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Lawrence of Arabia (1962)', 'American History X (1998)', 'Streetcar Named Desire, A (1951)']
#
#
# Recommendations for User 89: ['Good bye, Lenin! (2003)', 'Dangerous Liaisons (1988)', 'Three Colors: White (Trzy kolory: Bialy) (1994)', "Rosemary's Baby (1968)", 'Shooter (2007)']
#
#
# Recommendations for User 90: ['Grand Day Out with Wallace and Gromit, A (1989)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Casablanca (1942)', "Monty Python's And Now for Something Completely Different (1971)"]
#
#
# Recommendations for User 91: ['Guardians of the Galaxy (2014)', 'Lost in Translation (2003)', 'American Beauty (1999)', 'Big Lebowski, The (1998)', 'Departed, The (2006)']
#
#
# Recommendations for User 93: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Streetcar Named Desire, A (1951)', 'Paths of Glory (1957)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 96: ['Shawshank Redemption, The (1994)', 'Seven (a.k.a. Se7en) (1995)', 'Hoop Dreams (1994)', 'Bridge on the River Kwai, The (1957)', 'Eternal Sunshine of the Spotless Mind (2004)']
#
#
# Recommendations for User 98: ['Streetcar Named Desire, A (1951)', 'Grave of the Fireflies (Hotaru no haka) (1988)', 'Dark Knight, The (2008)', 'American History X (1998)', 'Unforgiven (1992)']
#
#
# Recommendations for User 103: ['Seven (a.k.a. Se7en) (1995)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Streetcar Named Desire, A (1951)', 'Blade Runner (1982)', 'Monty Python and the Holy Grail (1975)']
#
#
# Recommendations for User 107: ["Monty Python's And Now for Something Completely Different (1971)", 'Departed, The (2006)', 'American History X (1998)', 'Rebecca (1940)', 'Boondock Saints, The (2000)']
#
#
# Recommendations for User 112: ['Godfather, The (1972)', 'Ran (1985)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Lawrence of Arabia (1962)', 'Boot, Das (Boat, The) (1981)']
#
#
# Recommendations for User 119: ['Unforgiven (1992)', 'Goodfellas (1990)', 'Serenity (2005)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)']
#
#
# Recommendations for User 121: ['Departed, The (2006)', 'Lawrence of Arabia (1962)', 'Fight Club (1999)', 'Eternal Sunshine of the Spotless Mind (2004)', 'In Bruges (2008)']
#
#
# Recommendations for User 124: ['Lawrence of Arabia (1962)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Amadeus (1984)']
#
#
# Recommendations for User 130: ['Star Wars: Episode IV - A New Hope (1977)', 'Amadeus (1984)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Usual Suspects, The (1995)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"]
#
#
# Recommendations for User 132: ['Streetcar Named Desire, A (1951)', 'Boot, Das (Boat, The) (1981)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Amadeus (1984)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 134: ['Shawshank Redemption, The (1994)', 'Monty Python and the Holy Grail (1975)', 'There Will Be Blood (2007)', 'Godfather: Part II, The (1974)', 'Kiss Kiss Bang Bang (2005)']
#
#
# Recommendations for User 135: ['Apocalypse Now (1979)', 'Requiem for a Dream (2000)', 'Philadelphia Story, The (1940)', 'Rear Window (1954)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 137: ['Double Indemnity (1944)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Adaptation (2002)', 'Usual Suspects, The (1995)', 'Notorious (1946)']
#
#
# Recommendations for User 140: ['Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)', 'Clerks II (2006)', 'Wallace & Gromit: The Wrong Trousers (1993)', 'Eastern Promises (2007)', 'Fear and Loathing in Las Vegas (1998)']
#
#
# Recommendations for User 141: ['Patton (1970)', 'Eternal Sunshine of the Spotless Mind (2004)', 'On the Waterfront (1954)', 'North by Northwest (1959)', 'Fantastic Mr. Fox (2009)']
#
#
# Recommendations for User 144: ['Casablanca (1942)', 'Streetcar Named Desire, A (1951)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Lawrence of Arabia (1962)', 'Philadelphia Story, The (1940)']
#
#
# Recommendations for User 145: ['Hoop Dreams (1994)', 'Whiplash (2014)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", "One Flew Over the Cuckoo's Nest (1975)", 'Princess Bride, The (1987)']
#
#
# Recommendations for User 151: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Dark Knight, The (2008)', 'His Girl Friday (1940)', 'Streetcar Named Desire, A (1951)', 'Princess Bride, The (1987)']
#
#
# Recommendations for User 153: ['Lord of the Rings: The Return of the King, The (2003)', 'Monty Python and the Holy Grail (1975)', 'Usual Suspects, The (1995)', 'Philadelphia Story, The (1940)', 'Young Frankenstein (1974)']
#
#
# Recommendations for User 155: ['Life Is Beautiful (La Vita è bella) (1997)', 'Casablanca (1942)', 'Lawrence of Arabia (1962)', 'Streetcar Named Desire, A (1951)', 'Philadelphia Story, The (1940)']
#
#
# Recommendations for User 156: ['Glory (1989)', 'Streetcar Named Desire, A (1951)', 'Day of the Doctor, The (2013)', 'Boot, Das (Boat, The) (1981)', 'Shining, The (1980)']
#
#
# Recommendations for User 159: ['Lion King, The (1994)', 'Hoop Dreams (1994)', 'Hedwig and the Angry Inch (2000)', 'In the Name of the Father (1993)', 'Harry Potter and the Deathly Hallows: Part 1 (2010)']
#
#
# Recommendations for User 160: ['Producers, The (1968)', 'Maltese Falcon, The (1941)', 'Rosencrantz and Guildenstern Are Dead (1990)', 'Casablanca (1942)', 'In the Heat of the Night (1967)']
#
#
# Recommendations for User 161: ['Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Princess Bride, The (1987)', 'Streetcar Named Desire, A (1951)', 'Amadeus (1984)', 'Ran (1985)']
#
#
# Recommendations for User 166: ['Lawrence of Arabia (1962)', 'Boondock Saints, The (2000)', 'There Will Be Blood (2007)', 'Dark Knight, The (2008)', 'Touch of Evil (1958)']
#
#
# Recommendations for User 167: ["Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Philadelphia Story, The (1940)', "King's Speech, The (2010)", 'Miracle on 34th Street (1947)']
#
#
# Recommendations for User 169: ['Kiss Kiss Bang Bang (2005)', 'Spotlight (2015)', 'Lawrence of Arabia (1962)', 'Patton (1970)', 'Shining, The (1980)']
#
#
# Recommendations for User 171: ['Usual Suspects, The (1995)', 'Braveheart (1995)', 'Hoop Dreams (1994)', 'Lion King, The (1994)', "Schindler's List (1993)"]
#
#
# Recommendations for User 177: ['In the Name of the Father (1993)', 'Cool Hand Luke (1967)', 'Conversation, The (1974)', 'Evil Dead II (Dead by Dawn) (1987)', 'Day of the Doctor, The (2013)']
#
#
# Recommendations for User 178: ['Lawrence of Arabia (1962)', 'Hoop Dreams (1994)', 'Unforgiven (1992)', 'Jaws (1975)', 'Full Metal Jacket (1987)']
#
#
# Recommendations for User 179: ['Philadelphia Story, The (1940)', 'On the Waterfront (1954)', 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'Eternal Sunshine of the Spotless Mind (2004)', 'Hoop Dreams (1994)']
#
#
# Recommendations for User 182: ['Wolf of Wall Street, The (2013)', 'Producers, The (1968)', 'Sting, The (1973)', 'Seven Samurai (Shichinin no samurai) (1954)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)']
#
#
# Recommendations for User 185: ['Cool Hand Luke (1967)', 'Lawrence of Arabia (1962)', 'Streetcar Named Desire, A (1951)', 'Casablanca (1942)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 186: ['Dark Knight, The (2008)', 'Boondock Saints, The (2000)', 'FLCL (2000)', 'Casablanca (1942)', 'Boot, Das (Boat, The) (1981)']
#
#
# Recommendations for User 191: ['Boot, Das (Boat, The) (1981)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'To Catch a Thief (1955)', 'Amadeus (1984)', 'Godfather, The (1972)']
#
#
# Recommendations for User 193: ['Usual Suspects, The (1995)', 'Fargo (1996)', 'Ran (1985)', 'Lawrence of Arabia (1962)', 'Apocalypse Now (1979)']
#
#
# Recommendations for User 200: ['Lawrence of Arabia (1962)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Guardians of the Galaxy (2014)', 'Kingsman: The Secret Service (2015)']
#
#
# Recommendations for User 201: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Godfather, The (1972)', "Schindler's List (1993)", 'Hoop Dreams (1994)', 'Rear Window (1954)']
#
#
# Recommendations for User 202: ["One Flew Over the Cuckoo's Nest (1975)", 'Wallace & Gromit: The Wrong Trousers (1993)', 'Goodfellas (1990)', 'Philadelphia Story, The (1940)', 'Adaptation (2002)']
#
#
# Recommendations for User 206: ['Godfather: Part II, The (1974)', 'Shawshank Redemption, The (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"]
#
#
# Recommendations for User 213: ['Hustler, The (1961)', 'Silence of the Lambs, The (1991)', 'To Catch a Thief (1955)', 'Goodfellas (1990)', 'Rear Window (1954)']
#
#
# Recommendations for User 214: ['Shawshank Redemption, The (1994)', 'Pulp Fiction (1994)', 'Streetcar Named Desire, A (1951)', 'Rear Window (1954)', "One Flew Over the Cuckoo's Nest (1975)"]
#
#
# Recommendations for User 216: ['Lawrence of Arabia (1962)', '12 Angry Men (1957)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Boondock Saints, The (2000)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)']
#
#
# Recommendations for User 217: ['Casino (1995)', 'Goodfellas (1990)', 'Spotlight (2015)', 'Girl with the Dragon Tattoo, The (Män som hatar kvinnor) (2009)', 'Shawshank Redemption, The (1994)']
#
#
# Recommendations for User 219: ["Schindler's List (1993)", "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Toy Story 3 (2010)', 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'Apocalypse Now (1979)']
#
#
# Recommendations for User 220: ['There Will Be Blood (2007)', 'Bridge on the River Kwai, The (1957)', 'Beautiful Mind, A (2001)', 'Hoop Dreams (1994)', 'In the Name of the Father (1993)']
#
#
# Recommendations for User 223: ['Cool Hand Luke (1967)', 'Lawrence of Arabia (1962)', 'Grave of the Fireflies (Hotaru no haka) (1988)', 'Forrest Gump (1994)', 'Streetcar Named Desire, A (1951)']
#
#
# Recommendations for User 226: ['Shawshank Redemption, The (1994)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Usual Suspects, The (1995)', 'Fish Called Wanda, A (1988)']
#
#
# Recommendations for User 229: ['Lawrence of Arabia (1962)', 'Fight Club (1999)', 'Spotlight (2015)', 'Fargo (1996)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"]
#
#
# Recommendations for User 232: ['Lawrence of Arabia (1962)', 'Usual Suspects, The (1995)', 'Boogie Nights (1997)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Philadelphia Story, The (1940)']
#
#
# Recommendations for User 233: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'There Will Be Blood (2007)', 'Lawrence of Arabia (1962)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Ran (1985)']
#
#
# Recommendations for User 234: ['Casablanca (1942)', 'Princess Bride, The (1987)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Some Like It Hot (1959)', 'Godfather: Part II, The (1974)']
#
#
# Recommendations for User 239: ['Life Is Beautiful (La Vita è bella) (1997)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Lawrence of Arabia (1962)', 'On the Waterfront (1954)', 'Femme Nikita, La (Nikita) (1990)']
#
#
# Recommendations for User 240: ['Boondock Saints, The (2000)', 'There Will Be Blood (2007)', 'To Catch a Thief (1955)', 'Streetcar Named Desire, A (1951)', 'Green Mile, The (1999)']
#
#
# Recommendations for User 247: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Hot Fuzz (2007)', 'Streetcar Named Desire, A (1951)', 'Jaws (1975)']
#
#
# Recommendations for User 249: ['Grand Day Out with Wallace and Gromit, A (1989)', 'Princess Bride, The (1987)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Old Boy (2003)', 'Ran (1985)']
#
#
# Recommendations for User 252: ['Shawshank Redemption, The (1994)', 'Silence of the Lambs, The (1991)', 'Amadeus (1984)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
#
#
# Recommendations for User 254: ['12 Angry Men (1957)', 'High Noon (1952)', 'Dark Knight, The (2008)', 'Boot, Das (Boat, The) (1981)', 'Raging Bull (1980)']
#
#
# Recommendations for User 263: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', "Guess Who's Coming to Dinner (1967)", 'Godfather, The (1972)', 'Departed, The (2006)', 'Rear Window (1954)']
#
#
# Recommendations for User 264: ['Lawrence of Arabia (1962)', 'Streetcar Named Desire, A (1951)', 'Philadelphia Story, The (1940)', 'Usual Suspects, The (1995)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"]
#
#
# Recommendations for User 266: ['Kill Bill: Vol. 1 (2003)', 'Akira (1988)', 'Godfather: Part II, The (1974)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', "One Flew Over the Cuckoo's Nest (1975)"]
#
#
# Recommendations for User 269: ['Reservoir Dogs (1992)', 'Shawshank Redemption, The (1994)', 'Princess Bride, The (1987)', 'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', 'Pulp Fiction (1994)']
#
#
# Recommendations for User 270: ['Shawshank Redemption, The (1994)', 'Casablanca (1942)', 'Lord of the Rings: The Return of the King, The (2003)', 'In the Name of the Father (1993)', 'Monty Python and the Holy Grail (1975)']
#
#
# Recommendations for User 273: ["Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Shawshank Redemption, The (1994)', 'There Will Be Blood (2007)', 'Philadelphia Story, The (1940)']
#
#
# Recommendations for User 274: ['Grand Day Out with Wallace and Gromit, A (1989)', 'Ran (1985)', 'Hustler, The (1961)', "Singin' in the Rain (1952)", 'Logan (2017)']
#
#
# Recommendations for User 275: ['Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)', 'Grand Day Out with Wallace and Gromit, A (1989)', 'Fugitive, The (1993)', 'Jaws (1975)', 'Watchmen (2009)']
#
#
# Recommendations for User 276: ['Usual Suspects, The (1995)', 'Hoop Dreams (1994)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Dazed and Confused (1993)']
#
#
# Recommendations for User 277: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Fight Club (1999)', 'Goodfellas (1990)', 'Brazil (1985)', 'Eternal Sunshine of the Spotless Mind (2004)']
#
#
# Recommendations for User 279: ['Wallace & Gromit: The Best of Aardman Animation (1996)', 'Outlaw Josey Wales, The (1976)', 'Grand Day Out with Wallace and Gromit, A (1989)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Godfather: Part II, The (1974)']
#
#
# Recommendations for User 280: ['Fight Club (1999)', 'Pulp Fiction (1994)', 'Lawrence of Arabia (1962)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Boot, Das (Boat, The) (1981)']
#
#
# Recommendations for User 282: ['Lawrence of Arabia (1962)', 'Boondock Saints, The (2000)', 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'My Fair Lady (1964)', 'Streetcar Named Desire, A (1951)']
#
#
# Recommendations for User 283: ['Matrix, The (1999)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Casablanca (1942)', 'Godfather, The (1972)', 'Life Is Beautiful (La Vita è bella) (1997)']
#
#
# Recommendations for User 288: ['Godfather, The (1972)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Usual Suspects, The (1995)', 'Boondock Saints, The (2000)', 'Trainspotting (1996)']
#
#
# Recommendations for User 290: ['Wallace & Gromit: The Wrong Trousers (1993)', 'Hustler, The (1961)', 'Boogie Nights (1997)', 'Young Frankenstein (1974)', 'Paths of Glory (1957)']
#
#
# Recommendations for User 291: ['Godfather, The (1972)', 'Blade Runner (1982)', 'Streetcar Named Desire, A (1951)', 'Usual Suspects, The (1995)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 292: ["Schindler's List (1993)", 'In the Name of the Father (1993)', 'Run Lola Run (Lola rennt) (1998)', 'Billy Elliot (2000)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 293: ['12 Angry Men (1957)', 'Shawshank Redemption, The (1994)', 'In the Name of the Father (1993)', 'Departed, The (2006)', 'Evil Dead II (Dead by Dawn) (1987)']
#
#
# Recommendations for User 298: ['Sting, The (1973)', 'Grand Day Out with Wallace and Gromit, A (1989)', 'Yojimbo (1961)', "Schindler's List (1993)", 'Toy Story 3 (2010)']
#
#
# Recommendations for User 304: ['Dark Knight, The (2008)', 'Fear and Loathing in Las Vegas (1998)', "All the President's Men (1976)", 'Cool Hand Luke (1967)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 307: ['Amadeus (1984)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Dark Knight Rises, The (2012)', 'True Grit (2010)', 'Unforgiven (1992)']
#
#
# Recommendations for User 314: ['Spotlight (2015)', "Monty Python's And Now for Something Completely Different (1971)", 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Hero (Ying xiong) (2002)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 322: ['Hoop Dreams (1994)', 'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', 'Boogie Nights (1997)', 'Goodfellas (1990)', 'Happiness (1998)']
#
#
# Recommendations for User 323: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Touch of Evil (1958)', 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'Hoop Dreams (1994)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"]
#
#
# Recommendations for User 328: ['Seven Samurai (Shichinin no samurai) (1954)', 'Raging Bull (1980)', 'Some Like It Hot (1959)', 'North by Northwest (1959)', 'Dancer in the Dark (2000)']
#
#
# Recommendations for User 330: ["Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Hoop Dreams (1994)', 'Little Big Man (1970)', 'Kiss Kiss Bang Bang (2005)', 'Ghost Dog: The Way of the Samurai (1999)']
#
#
# Recommendations for User 332: ['Godfather, The (1972)', 'Streetcar Named Desire, A (1951)', 'Star Wars: Episode IV - A New Hope (1977)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Kiss Kiss Bang Bang (2005)']
#
#
# Recommendations for User 334: ['Lawrence of Arabia (1962)', 'Wallace & Gromit: The Wrong Trousers (1993)', 'Usual Suspects, The (1995)', 'Hoop Dreams (1994)', 'Unforgiven (1992)']
#
#
# Recommendations for User 336: ['Philadelphia Story, The (1940)', 'Goodfellas (1990)', 'Lawrence of Arabia (1962)', "One Flew Over the Cuckoo's Nest (1975)", 'Boondock Saints, The (2000)']
#
#
# Recommendations for User 337: ['In the Name of the Father (1993)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Rear Window (1954)', 'North by Northwest (1959)', 'Streetcar Named Desire, A (1951)']
#
#
# Recommendations for User 339: ['Whiplash (2014)', 'Usual Suspects, The (1995)', 'Unforgiven (1992)', 'Monty Python and the Holy Grail (1975)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 341: ['To Catch a Thief (1955)', 'Departed, The (2006)', 'Shining, The (1980)', 'Guardians of the Galaxy (2014)', 'Usual Suspects, The (1995)']
#
#
# Recommendations for User 347: ['Whiplash (2014)', 'Streetcar Named Desire, A (1951)', 'Boondock Saints, The (2000)', 'Green Mile, The (1999)', "Singin' in the Rain (1952)"]
#
#
# Recommendations for User 350: ['Boondock Saints, The (2000)', 'Cool Hand Luke (1967)', 'Lawrence of Arabia (1962)', 'Apocalypse Now (1979)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
#
#
# Recommendations for User 353: ['Apocalypse Now (1979)', 'Shining, The (1980)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Godfather: Part II, The (1974)', 'Aliens (1986)']
#
#
# Recommendations for User 357: ['Great Escape, The (1963)', 'Boogie Nights (1997)', 'Grave of the Fireflies (Hotaru no haka) (1988)', 'Whiplash (2014)', 'Lord of the Rings: The Fellowship of the Ring, The (2001)']
#
#
# Recommendations for User 359: ['Shawshank Redemption, The (1994)', 'Lord of the Rings: The Fellowship of the Ring, The (2001)', 'Forrest Gump (1994)', 'Lord of the Rings: The Return of the King, The (2003)', 'Sound of Music, The (1965)']
#
#
# Recommendations for User 364: ['Dark Knight, The (2008)', 'Ran (1985)', 'American History X (1998)', 'To Catch a Thief (1955)', 'City of God (Cidade de Deus) (2002)']
#
#
# Recommendations for User 367: ['Cool Hand Luke (1967)', 'Airplane! (1980)', 'Mary and Max (2009)', 'Rear Window (1954)', 'Raging Bull (1980)']
#
#
# Recommendations for User 372: ["Monty Python's The Meaning of Life (1983)", 'Eternal Sunshine of the Spotless Mind (2004)', 'Captain Phillips (2013)', 'Traffic (2000)', 'American History X (1998)']
#
#
# Recommendations for User 373: ['Godfather, The (1972)', 'Godfather: Part II, The (1974)', 'Reservoir Dogs (1992)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)', 'Glory (1989)']
#
#
# Recommendations for User 378: ['Boondock Saints, The (2000)', 'Lawrence of Arabia (1962)', 'Streetcar Named Desire, A (1951)', 'Boot, Das (Boat, The) (1981)', '3:10 to Yuma (2007)']
#
#
# Recommendations for User 380: ['Departed, The (2006)', "Schindler's List (1993)", 'Life Is Beautiful (La Vita è bella) (1997)', 'Hustler, The (1961)', 'Bonnie and Clyde (1967)']
#
#
# Recommendations for User 381: ['12 Angry Men (1957)', 'WALL·E (2008)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'On the Waterfront (1954)', 'Casablanca (1942)']
#
#
# Recommendations for User 382: ['Terminator 2: Judgment Day (1991)', 'Wallace & Gromit: The Wrong Trousers (1993)', 'Amadeus (1984)', 'Grand Day Out with Wallace and Gromit, A (1989)', 'Blade Runner (1982)']
#
#
# Recommendations for User 385: ['Reservoir Dogs (1992)', "One Flew Over the Cuckoo's Nest (1975)", 'Casino Royale (2006)', 'Hero (Ying xiong) (2002)', "Schindler's List (1993)"]
#
#
# Recommendations for User 389: ['Hoop Dreams (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)', 'Boogie Nights (1997)', 'Wallace & Gromit: The Wrong Trousers (1993)']
#
#
# Recommendations for User 391: ['Adaptation (2002)', '12 Angry Men (1957)', 'Ghost Dog: The Way of the Samurai (1999)', 'Manchurian Candidate, The (1962)', 'Moonrise Kingdom (2012)']
#
#
# Recommendations for User 396: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Matrix, The (1999)', 'Lawrence of Arabia (1962)', 'Goodfellas (1990)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
#
#
# Recommendations for User 399: ['Shining, The (1980)', 'Lawrence of Arabia (1962)', 'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)', 'Boondock Saints, The (2000)', 'Evil Dead II (Dead by Dawn) (1987)']
#
#
# Recommendations for User 401: ['Princess Bride, The (1987)', 'To Catch a Thief (1955)', 'Rear Window (1954)', "Rosemary's Baby (1968)", 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 411: ['Great Escape, The (1963)', 'Fight Club (1999)', 'Reservoir Dogs (1992)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
#
#
# Recommendations for User 412: ['Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)', 'In Bruges (2008)', 'Glory (1989)', 'In the Name of the Father (1993)', 'Hustler, The (1961)']
#
#
# Recommendations for User 414: ['My Fair Lady (1964)', 'Life Is Beautiful (La Vita è bella) (1997)', 'Yojimbo (1961)', 'Neon Genesis Evangelion: The End of Evangelion (Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni) (1997)', 'Hoop Dreams (1994)']
#
#
# Recommendations for User 420: ['Usual Suspects, The (1995)', 'Great Escape, The (1963)', 'There Will Be Blood (2007)', 'Star Wars: Episode IV - A New Hope (1977)', 'City of God (Cidade de Deus) (2002)']
#
#
# Recommendations for User 422: ['12 Angry Men (1957)', 'Usual Suspects, The (1995)', 'Pulp Fiction (1994)', 'City of God (Cidade de Deus) (2002)', 'Lord of the Rings: The Fellowship of the Ring, The (2001)']
#
#
# Recommendations for User 432: ['Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Young Frankenstein (1974)', 'Glory (1989)', 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)', "Rosemary's Baby (1968)"]
#
#
# Recommendations for User 434: ['Godfather: Part II, The (1974)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Sting, The (1973)', 'L.A. Confidential (1997)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 436: ['Lawrence of Arabia (1962)', 'Spotlight (2015)', 'Godfather, The (1972)', 'Departed, The (2006)', 'In Bruges (2008)']
#
#
# Recommendations for User 438: ['Godfather, The (1972)', 'Hustler, The (1961)', 'Spotlight (2015)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Toy Story 3 (2010)']
#
#
# Recommendations for User 443: ['Cool Hand Luke (1967)', 'Rear Window (1954)', "Guess Who's Coming to Dinner (1967)", 'Dark Knight, The (2008)', "Singin' in the Rain (1952)"]
#
#
# Recommendations for User 448: ['Shawshank Redemption, The (1994)', 'There Will Be Blood (2007)', 'Amadeus (1984)', 'North by Northwest (1959)', 'Graduate, The (1967)']
#
#
# Recommendations for User 451: ['Shawshank Redemption, The (1994)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Apocalypse Now (1979)', 'Manchurian Candidate, The (1962)', 'Eternal Sunshine of the Spotless Mind (2004)']
#
#
# Recommendations for User 453: ['Some Like It Hot (1959)', 'Notorious (1946)', 'Lawrence of Arabia (1962)', 'Rear Window (1954)', 'Hoop Dreams (1994)']
#
#
# Recommendations for User 456: ['Shawshank Redemption, The (1994)', 'American History X (1998)', 'Matrix, The (1999)', "Schindler's List (1993)", 'Fight Club (1999)']
#
#
# Recommendations for User 460: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Princess Bride, The (1987)', 'Casablanca (1942)', 'Rear Window (1954)', 'Goodfellas (1990)']
#
#
# Recommendations for User 462: ['Apartment, The (1960)', 'Perks of Being a Wallflower, The (2012)', 'Paths of Glory (1957)', '12 Angry Men (1957)', "Singin' in the Rain (1952)"]
#
#
# Recommendations for User 468: ['Life Is Beautiful (La Vita è bella) (1997)', 'Cool Hand Luke (1967)', "Schindler's List (1993)", 'Dark Knight, The (2008)', 'Great Escape, The (1963)']
#
#
# Recommendations for User 469: ['Fight Club (1999)', 'Seven Samurai (Shichinin no samurai) (1954)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Lord of the Rings: The Two Towers, The (2002)', 'Adaptation (2002)']
#
#
# Recommendations for User 470: ['Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Matrix, The (1999)', 'Lawrence of Arabia (1962)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Fight Club (1999)']
#
#
# Recommendations for User 471: ['Shawshank Redemption, The (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Departed, The (2006)', 'Casablanca (1942)', 'In the Name of the Father (1993)']
#
#
# Recommendations for User 474: ['Snatch (2000)', 'Bound (1996)', 'Boondock Saints, The (2000)', 'Moonrise Kingdom (2012)', 'There Will Be Blood (2007)']
#
#
# Recommendations for User 476: ['Godfather, The (1972)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Great Escape, The (1963)', 'Wallace & Gromit: The Wrong Trousers (1993)', 'Usual Suspects, The (1995)']
#
#
# Recommendations for User 477: ['Usual Suspects, The (1995)', 'To Catch a Thief (1955)', 'Good Will Hunting (1997)', 'Braveheart (1995)', 'American History X (1998)']
#
#
# Recommendations for User 480: ['Dark Knight, The (2008)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Toy Story 3 (2010)', 'Rear Window (1954)', 'L.A. Confidential (1997)']
#
#
# Recommendations for User 483: ['Heavenly Creatures (1994)', 'Reservoir Dogs (1992)', 'Donnie Darko (2001)', 'Old Boy (2003)', 'Rear Window (1954)']
#
#
# Recommendations for User 484: ['Casablanca (1942)', 'In the Name of the Father (1993)', 'Spotlight (2015)', 'Star Wars: Episode IV - A New Hope (1977)', 'Cool Hand Luke (1967)']
#
#
# Recommendations for User 488: ['Godfather: Part II, The (1974)', 'Forrest Gump (1994)', 'Lawrence of Arabia (1962)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Memento (2000)']
#
#
# Recommendations for User 490: ['Shawshank Redemption, The (1994)', 'Usual Suspects, The (1995)', 'Rear Window (1954)', 'Godfather: Part II, The (1974)', 'Godfather, The (1972)']
#
#
# Recommendations for User 492: ['There Will Be Blood (2007)', 'Whiplash (2014)', 'His Girl Friday (1940)', 'To Catch a Thief (1955)', 'Unforgiven (1992)']
#
#
# Recommendations for User 500: ['Apocalypse Now (1979)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Shawshank Redemption, The (1994)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
#
#
# Recommendations for User 504: ['Léon: The Professional (a.k.a. The Professional) (Léon) (1994)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Shawshank Redemption, The (1994)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 509: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Streetcar Named Desire, A (1951)', 'Departed, The (2006)', 'Rear Window (1954)', 'Grave of the Fireflies (Hotaru no haka) (1988)']
#
#
# Recommendations for User 514: ["Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Memento (2000)', 'Philadelphia Story, The (1940)', 'Shawshank Redemption, The (1994)', 'Godfather: Part II, The (1974)']
#
#
# Recommendations for User 517: ['Buena Vista Social Club (1999)', 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'Die Hard (1988)', 'The Artist (2011)', 'Touch of Evil (1958)']
#
#
# Recommendations for User 522: ['His Girl Friday (1940)', 'Deliverance (1972)', 'Amadeus (1984)', 'Streetcar Named Desire, A (1951)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 524: ['For a Few Dollars More (Per qualche dollaro in più) (1965)', 'Reservoir Dogs (1992)', 'Guardians of the Galaxy (2014)', 'Fear and Loathing in Las Vegas (1998)', 'Kiss Kiss Bang Bang (2005)']
#
#
# Recommendations for User 525: ['Reservoir Dogs (1992)', 'Lawrence of Arabia (1962)', 'On the Waterfront (1954)', 'Aliens (1986)', 'Hoop Dreams (1994)']
#
#
# Recommendations for User 528: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Shaun of the Dead (2004)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Whiplash (2014)', 'Boogie Nights (1997)']
#
#
# Recommendations for User 529: ['Forrest Gump (1994)', 'Lawrence of Arabia (1962)', 'Shawshank Redemption, The (1994)', 'Good Will Hunting (1997)', 'Hero (Ying xiong) (2002)']
#
#
# Recommendations for User 533: ['Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Goodfellas (1990)', 'Godfather, The (1972)', 'Monty Python and the Holy Grail (1975)']
#
#
# Recommendations for User 534: ['Hoop Dreams (1994)', 'Lawrence of Arabia (1962)', "One Flew Over the Cuckoo's Nest (1975)", 'Spotlight (2015)', 'Ran (1985)']
#
#
# Recommendations for User 541: ['Casino (1995)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Shining, The (1980)', 'Godfather: Part II, The (1974)', 'Inglourious Basterds (2009)']
#
#
# Recommendations for User 544: ['Usual Suspects, The (1995)', 'Hoop Dreams (1994)', 'Shawshank Redemption, The (1994)', 'In the Name of the Father (1993)', 'Casablanca (1942)']
#
#
# Recommendations for User 550: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Lawrence of Arabia (1962)', 'Apocalypse Now (1979)', 'Fight Club (1999)', 'Star Wars: Episode IV - A New Hope (1977)']
#
#
# Recommendations for User 555: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Eternal Sunshine of the Spotless Mind (2004)', 'Some Like It Hot (1959)', 'To Catch a Thief (1955)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)']
#
#
# Recommendations for User 559: ['Lord of the Rings: The Fellowship of the Ring, The (2001)', 'Godfather, The (1972)', 'Reservoir Dogs (1992)', 'Departed, The (2006)', 'Princess Bride, The (1987)']
#
#
# Recommendations for User 560: ['Lawrence of Arabia (1962)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Seven Samurai (Shichinin no samurai) (1954)', 'Boot, Das (Boat, The) (1981)']
#
#
# Recommendations for User 561: ['Godfather, The (1972)', 'Godfather: Part II, The (1974)', 'Rear Window (1954)', 'Hustler, The (1961)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 562: ['Rear Window (1954)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Streetcar Named Desire, A (1951)', 'Lawrence of Arabia (1962)', 'Glory (1989)']
#
#
# Recommendations for User 567: ['Chinatown (1974)', 'Pulp Fiction (1994)', 'Kiss Kiss Bang Bang (2005)', 'Fight Club (1999)', 'Reservoir Dogs (1992)']
#
#
# Recommendations for User 570: ['Lawrence of Arabia (1962)', 'Bound (1996)', 'Three Billboards Outside Ebbing, Missouri (2017)', 'Reservoir Dogs (1992)', 'Life Is Beautiful (La Vita è bella) (1997)']
#
#
# Recommendations for User 572: ['Lord of the Rings: The Return of the King, The (2003)', 'Gran Torino (2008)', 'In Bruges (2008)', 'Paths of Glory (1957)', 'Inglourious Basterds (2009)']
#
#
# Recommendations for User 573: ['Whiplash (2014)', "Singin' in the Rain (1952)", 'Bonnie and Clyde (1967)', 'Grand Day Out with Wallace and Gromit, A (1989)', 'Bridge on the River Kwai, The (1957)']
#
#
# Recommendations for User 579: ['North by Northwest (1959)', 'Philadelphia Story, The (1940)', 'Grand Day Out with Wallace and Gromit, A (1989)', 'In Bruges (2008)', 'Shawshank Redemption, The (1994)']
#
#
# Recommendations for User 580: ['Lawrence of Arabia (1962)', 'Life Is Beautiful (La Vita è bella) (1997)', 'No Country for Old Men (2007)', '3:10 to Yuma (2007)', 'Zero Effect (1998)']
#
#
# Recommendations for User 584: ['Persuasion (1995)', 'Shawshank Redemption, The (1994)', "Schindler's List (1993)", 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)']
#
#
# Recommendations for User 587: ['Shining, The (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Three Billboards Outside Ebbing, Missouri (2017)', 'Shawshank Redemption, The (1994)', 'Rear Window (1954)']
#
#
# Recommendations for User 590: ['Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Amadeus (1984)', 'Manchurian Candidate, The (1962)', 'Seven Samurai (Shichinin no samurai) (1954)', 'Toy Story 3 (2010)']
#
#
# Recommendations for User 596: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Maltese Falcon, The (1941)', 'Shawshank Redemption, The (1994)', 'Streetcar Named Desire, A (1951)', 'Wallace & Gromit: The Wrong Trousers (1993)']
#
#
# Recommendations for User 597: ['Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', "Schindler's List (1993)", 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Citizen Kane (1941)']
#
#
# Recommendations for User 599: ['In Bruges (2008)', "Schindler's List (1993)", 'North by Northwest (1959)', 'Harold and Maude (1971)', 'Little Big Man (1970)']
#
#
# Recommendations for User 600: ['Godfather: Part II, The (1974)', 'To Catch a Thief (1955)', 'Departed, The (2006)', 'Guardians of the Galaxy (2014)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)']
#
#
# Recommendations for User 601: ['Lawrence of Arabia (1962)', 'Goodfellas (1990)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Streetcar Named Desire, A (1951)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 603: ['Lives of Others, The (Das leben der Anderen) (2006)', 'Usual Suspects, The (1995)', 'Perfect Blue (1997)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Patton (1970)']
#
#
# Recommendations for User 604: ['Saving Private Ryan (1998)', 'Snatch (2000)', 'Fight Club (1999)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 605: ['In Bruges (2008)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Inglourious Basterds (2009)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Fugitive, The (1993)']
#
#
# Recommendations for User 606: ['Office Space (1999)', 'Boot, Das (Boat, The) (1981)', 'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', 'Boondock Saints, The (2000)', 'Dark Knight, The (2008)']
#
#
# Recommendations for User 607: ['Streetcar Named Desire, A (1951)', 'Casablanca (1942)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Apartment, The (1960)', 'Captain Phillips (2013)']
#
#
# Recommendations for User 608: ['Life Is Beautiful (La Vita è bella) (1997)', 'Departed, The (2006)', 'Brazil (1985)', 'WALL·E (2008)', 'Princess Bride, The (1987)']
#
#
# Recommendations for User 609: ['Princess Bride, The (1987)', 'Cool Hand Luke (1967)', 'Rear Window (1954)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'To Catch a Thief (1955)']
#
#
# Recommendations for User 610: ['Grand Day Out with Wallace and Gromit, A (1989)', 'Chinatown (1974)', 'Ran (1985)', 'Amadeus (1984)', 'South Park: Bigger, Longer and Uncut (1999)']
#
#
# Recommendations for User 6: ["Rosemary's Baby (1968)", 'Glory (1989)', 'Casablanca (1942)', 'Goodfellas (1990)', 'Prestige, The (2006)']
#
#
# Recommendations for User 8: ['Matrix, The (1999)', 'Lawrence of Arabia (1962)', 'Clerks (1994)', 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'Hoop Dreams (1994)']
#
#
# Recommendations for User 20: ['Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)', 'Shawshank Redemption, The (1994)', "One Flew Over the Cuckoo's Nest (1975)", 'Apocalypse Now (1979)', 'Monty Python and the Holy Grail (1975)']
#
#
# Recommendations for User 51: ['Pulp Fiction (1994)', 'Lord of the Rings: The Two Towers, The (2002)', 'Lord of the Rings: The Return of the King, The (2003)', 'Eternal Sunshine of the Spotless Mind (2004)', 'WALL·E (2008)']
#
#
# Recommendations for User 62: ['Rear Window (1954)', 'Lawrence of Arabia (1962)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Streetcar Named Desire, A (1951)', 'City of God (Cidade de Deus) (2002)']
#
#
# Recommendations for User 94: ['Apocalypse Now (1979)', 'Lawrence of Arabia (1962)', 'Goodfellas (1990)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Casablanca (1942)']
#
#
# Recommendations for User 104: ['Spotlight (2015)', 'Prisoners (2013)', 'Lawrence of Arabia (1962)', 'Gladiator (1992)', 'Airplane! (1980)']
#
#
# Recommendations for User 117: ['Casablanca (1942)', 'Boondock Saints, The (2000)', 'Fight Club (1999)', "Guess Who's Coming to Dinner (1967)", 'American History X (1998)']
#
#
# Recommendations for User 122: ['Hoop Dreams (1994)', 'Blade Runner (1982)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Maltese Falcon, The (1941)']
#
#
# Recommendations for User 125: ["Monty Python's The Meaning of Life (1983)", 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Snatch (2000)', "It's a Wonderful Life (1946)", 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
#
#
# Recommendations for User 149: ['Cool Hand Luke (1967)', 'Inglourious Basterds (2009)', 'Fight Club (1999)', 'Godfather, The (1972)', 'Lord of the Rings: The Fellowship of the Ring, The (2001)']
#
#
# Recommendations for User 221: ['Wallace & Gromit: The Wrong Trousers (1993)', 'American History X (1998)', 'Godfather: Part II, The (1974)', 'Glory (1989)', 'Boondock Saints, The (2000)']
#
#
# Recommendations for User 222: ['Grand Day Out with Wallace and Gromit, A (1989)', 'Evil Dead II (Dead by Dawn) (1987)', 'Casino (1995)', 'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', 'Princess Bride, The (1987)']
#
#
# Recommendations for User 230: ['Lord of the Rings: The Fellowship of the Ring, The (2001)', 'Boondock Saints, The (2000)', 'The Raid: Redemption (2011)', 'Being There (1979)', 'Streetcar Named Desire, A (1951)']
#
#
# Recommendations for User 259: ['Fight Club (1999)', 'Shawshank Redemption, The (1994)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Pulp Fiction (1994)']
#
#
# Recommendations for User 284: ['Streetcar Named Desire, A (1951)', 'Princess Bride, The (1987)', 'Fight Club (1999)', 'Miracle on 34th Street (1947)', 'Departed, The (2006)']
#
#
# ...
#
#
# Recommendations for User 210: ['Lawrence of Arabia (1962)', "Guess Who's Coming to Dinner (1967)", 'Streetcar Named Desire, A (1951)', 'Grave of the Fireflies (Hotaru no haka) (1988)', 'Shawshank Redemption, The (1994)']
#
#
# Recommendations for User 315: ['Shawshank Redemption, The (1994)', 'Streetcar Named Desire, A (1951)', 'North by Northwest (1959)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Touch of Evil (1958)']
#
#
# Recommendations for User 431: ['Philadelphia Story, The (1940)', 'Usual Suspects, The (1995)', 'Boondock Saints, The (2000)', 'Princess Bride, The (1987)', 'Shining, The (1980)']
#
#
# Recommendations for User 538: ['Shawshank Redemption, The (1994)', 'Great Escape, The (1963)', 'Little Big Man (1970)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Seven Samurai (Shichinin no samurai) (1954)']
#
#
# Recommendations for User 245: ['Shawshank Redemption, The (1994)', 'Grand Day Out with Wallace and Gromit, A (1989)', 'Rear Window (1954)', 'Spotlight (2015)', "One Flew Over the Cuckoo's Nest (1975)"]
#
#
# Recommendations for User 238: ['Shawshank Redemption, The (1994)', 'Lawrence of Arabia (1962)', 'In the Name of the Father (1993)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Life Is Beautiful (La Vita è bella) (1997)']
#
#
# Recommendations for User 416: ['Cool Hand Luke (1967)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Casablanca (1942)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)', 'Godfather, The (1972)']
#
#
# Recommendations for User 554: ['Avengers, The (2012)', 'Streetcar Named Desire, A (1951)', 'Ran (1985)', 'Bridge on the River Kwai, The (1957)', 'Pianist, The (2002)']
#
#
# Recommendations for User 218: ['Amadeus (1984)', 'Streetcar Named Desire, A (1951)', 'Usual Suspects, The (1995)', 'Great Escape, The (1963)', 'Pulp Fiction (1994)']
#
#
# Recommendations for User 55: ['Usual Suspects, The (1995)', 'Streetcar Named Desire, A (1951)', 'Brazil (1985)', 'Lawrence of Arabia (1962)', 'Some Like It Hot (1959)']
#
#
# Recommendations for User 461: ['To Catch a Thief (1955)', 'Eternal Sunshine of the Spotless Mind (2004)', 'Boondock Saints, The (2000)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Pulp Fiction (1994)']
#
#
# Recommendations for User 158: ['Casablanca (1942)', 'Streetcar Named Desire, A (1951)', 'Rear Window (1954)', 'Philadelphia Story, The (1940)', 'Wallace & Gromit: The Wrong Trousers (1993)']
#
#
# Recommendations for User 53: ['Heat (1995)', 'Casino (1995)', 'Sense and Sensibility (1995)', 'Persuasion (1995)', 'City of Lost Children, The (Cité des enfants perdus, La) (1995)']
#
#
# Recommendations for User 526: ["Guess Who's Coming to Dinner (1967)", 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'In the Name of the Father (1993)', 'Lawrence of Arabia (1962)', 'Boondock Saints, The (2000)']
#
#
# Recommendations for User 138: ['Touch of Evil (1958)', 'Cool Hand Luke (1967)', 'Lawrence of Arabia (1962)', 'Fight Club (1999)', 'Spotlight (2015)']
#
#
# Recommendations for User 101: ['Shawshank Redemption, The (1994)', 'Lawrence of Arabia (1962)', 'Star Wars: Episode IV - A New Hope (1977)', "Schindler's List (1993)", 'Godfather: Part II, The (1974)']
#
#
# Recommendations for User 25: ['Usual Suspects, The (1995)', 'Shawshank Redemption, The (1994)', 'Godfather, The (1972)', 'Rear Window (1954)', 'To Catch a Thief (1955)']
#
#
# Recommendations for User 281: ['Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Reservoir Dogs (1992)', 'Pulp Fiction (1994)', 'Fight Club (1999)', 'Departed, The (2006)']
#
#
# Recommendations for User 77: ['Godfather, The (1972)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Rear Window (1954)', 'Kiss Kiss Bang Bang (2005)', 'Casablanca (1942)']
#
#
# Recommendations for User 114: ['Streetcar Named Desire, A (1951)', 'Life Is Beautiful (La Vita è bella) (1997)', 'Hoop Dreams (1994)', 'Reservoir Dogs (1992)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 180: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Godfather: Part II, The (1974)', 'Rear Window (1954)', 'Memento (2000)', 'Brazil (1985)']
#
#
# Recommendations for User 205: ['Boondock Saints, The (2000)', 'Reservoir Dogs (1992)', 'Lost in Translation (2003)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Shawshank Redemption, The (1994)']
#
#
# Recommendations for User 212: ['Streetcar Named Desire, A (1951)', 'Casablanca (1942)', 'Cool Hand Luke (1967)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 231: ['Lawrence of Arabia (1962)', 'Goodfellas (1990)', 'Casablanca (1942)', 'Boondock Saints, The (2000)', 'Boot, Das (Boat, The) (1981)']
#
#
# Recommendations for User 407: ['Shawshank Redemption, The (1994)', 'Godfather, The (1972)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Forrest Gump (1994)', "Schindler's List (1993)"]
#
#
# Recommendations for User 459: ['Lawrence of Arabia (1962)', 'Streetcar Named Desire, A (1951)', 'Boondock Saints, The (2000)', 'Back to the Future (1985)', 'Wallace & Gromit: The Wrong Trousers (1993)']
#
#
# Recommendations for User 466: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Streetcar Named Desire, A (1951)', 'His Girl Friday (1940)', 'Goodfellas (1990)', 'Cool Hand Luke (1967)']
#
#
# Recommendations for User 487: ['Cool Hand Luke (1967)', 'Pulp Fiction (1994)', 'Boot, Das (Boat, The) (1981)', 'Departed, The (2006)', 'Streetcar Named Desire, A (1951)']
#
#
# Recommendations for User 516: ['Rear Window (1954)', 'Shawshank Redemption, The (1994)', 'Philadelphia Story, The (1940)', 'Silence of the Lambs, The (1991)', 'For a Few Dollars More (Per qualche dollaro in più) (1965)']
#
#
# Recommendations for User 582: ['Shawshank Redemption, The (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Good Will Hunting (1997)', '12 Angry Men (1957)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
#
#
# Recommendations for User 127: ['Shawshank Redemption, The (1994)', 'Brazil (1985)', "One Flew Over the Cuckoo's Nest (1975)", 'Reservoir Dogs (1992)', 'Boondock Saints, The (2000)']
#
#
# Recommendations for User 172: ['Rear Window (1954)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'North by Northwest (1959)', 'Godfather: Part II, The (1974)']
#
#
# Recommendations for User 67: ['Princess Bride, The (1987)', 'Three Billboards Outside Ebbing, Missouri (2017)', 'Usual Suspects, The (1995)', 'Hoop Dreams (1994)', 'Unforgiven (1992)']
#
#
# Recommendations for User 10: ['Boondock Saints, The (2000)', 'In the Name of the Father (1993)', 'Three Billboards Outside Ebbing, Missouri (2017)', 'Lawrence of Arabia (1962)', 'Notorious (1946)']
#
#
# Recommendations for User 575: ['Streetcar Named Desire, A (1951)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Brazil (1985)', 'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"]
#
#
# Recommendations for User 2: ['Eternal Sunshine of the Spotless Mind (2004)', 'Fight Club (1999)', 'Hoop Dreams (1994)', 'Graduate, The (1967)', 'Spotlight (2015)']
#
#
# Recommendations for User 65: ['Lawrence of Arabia (1962)', 'Godfather, The (1972)', 'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 106: ['Streetcar Named Desire, A (1951)', 'Lawrence of Arabia (1962)', 'Cool Hand Luke (1967)', "Rosemary's Baby (1968)", 'Boondock Saints, The (2000)']
#
#
# Recommendations for User 189: ['Amadeus (1984)', 'Lawrence of Arabia (1962)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'American History X (1998)', 'Boot, Das (Boat, The) (1981)']
#
#
# Recommendations for User 190: ['Lawrence of Arabia (1962)', 'Cool Hand Luke (1967)', 'Hoop Dreams (1994)', "Monty Python's And Now for Something Completely Different (1971)", 'Spotlight (2015)']
#
#
# Recommendations for User 209: ['Godfather: Part II, The (1974)', 'Pulp Fiction (1994)', "One Flew Over the Cuckoo's Nest (1975)", 'Monty Python and the Holy Grail (1975)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 258: ['Star Wars: Episode IV - A New Hope (1977)', 'Casablanca (1942)', 'Goodfellas (1990)', 'Kiss Kiss Bang Bang (2005)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 272: ['Great Escape, The (1963)', 'Lawrence of Arabia (1962)', 'Streetcar Named Desire, A (1951)', 'Casablanca (1942)', 'Grave of the Fireflies (Hotaru no haka) (1988)']
#
#
# Recommendations for User 300: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Lawrence of Arabia (1962)', 'Bridge on the River Kwai, The (1957)', "One Flew Over the Cuckoo's Nest (1975)", 'Lord of the Rings: The Return of the King, The (2003)']
#
#
# Recommendations for User 511: ['Lawrence of Arabia (1962)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Godfather, The (1972)', 'Star Wars: Episode IV - A New Hope (1977)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)']
#
#
# Recommendations for User 519: ['To Kill a Mockingbird (1962)', 'Princess Bride, The (1987)', 'Lawrence of Arabia (1962)', 'Maltese Falcon, The (1941)', 'Philadelphia Story, The (1940)']
#
#
# Recommendations for User 537: ['Lawrence of Arabia (1962)', "Singin' in the Rain (1952)", 'Blazing Saddles (1974)', 'On the Waterfront (1954)', 'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)']
#
#
# Recommendations for User 581: ['Godfather, The (1972)', "One Flew Over the Cuckoo's Nest (1975)", 'Cool Hand Luke (1967)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 499: ['Grand Day Out with Wallace and Gromit, A (1989)', 'Life Is Beautiful (La Vita è bella) (1997)', 'Monty Python and the Holy Grail (1975)', 'Fight Club (1999)', 'Godfather, The (1972)']
#
#
# Recommendations for User 333: ['Goodfellas (1990)', 'Great Escape, The (1963)', 'Shawshank Redemption, The (1994)', 'Fight Club (1999)', 'Philadelphia Story, The (1940)']
#
#
# Recommendations for User 143: ['Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Grand Day Out with Wallace and Gromit, A (1989)', 'Fargo (1996)', 'Happiness (1998)', 'Spotlight (2015)']
#
#
# Recommendations for User 148: ['Usual Suspects, The (1995)', 'Monty Python and the Holy Grail (1975)', 'Goodfellas (1990)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Shawshank Redemption, The (1994)']
#
#
# Recommendations for User 154: ['Hoop Dreams (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'North by Northwest (1959)', 'Lawrence of Arabia (1962)', 'Streetcar Named Desire, A (1951)']
#
#
# Recommendations for User 442: ['To Catch a Thief (1955)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Evil Dead II (Dead by Dawn) (1987)', 'American History X (1998)', 'Pulp Fiction (1994)']
#
#
# Recommendations for User 97: ['Rear Window (1954)', 'Departed, The (2006)', 'Shawshank Redemption, The (1994)', 'Dark Knight, The (2008)', 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)']
#
#
# Recommendations for User 324: ['Shawshank Redemption, The (1994)', 'Cool Hand Luke (1967)', 'Fight Club (1999)', 'Godfather: Part II, The (1974)', 'Apocalypse Now (1979)']
#
#
# Recommendations for User 157: ['Shawshank Redemption, The (1994)', 'Usual Suspects, The (1995)', 'Forrest Gump (1994)', 'Braveheart (1995)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)']
#
#
# Recommendations for User 175: ['Shawshank Redemption, The (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Rear Window (1954)', 'Bridge on the River Kwai, The (1957)', "One Flew Over the Cuckoo's Nest (1975)"]
#
#
# Recommendations for User 392: ['Shawshank Redemption, The (1994)', 'Eternal Sunshine of the Spotless Mind (2004)', 'Lawrence of Arabia (1962)', 'Chinatown (1974)', 'Goodfellas (1990)']
#
#
# Recommendations for User 547: ['Shawshank Redemption, The (1994)', 'Philadelphia Story, The (1940)', 'Maltese Falcon, The (1941)', 'Fight Club (1999)', 'Wallace & Gromit: The Best of Aardman Animation (1996)']
#
#
# Recommendations for User 388: ['Memento (2000)', 'Lawrence of Arabia (1962)', 'Boondock Saints, The (2000)', 'Life Is Beautiful (La Vita è bella) (1997)', 'Go (1999)']
#
#
# Recommendations for User 556: ['Pulp Fiction (1994)', 'Usual Suspects, The (1995)', 'Streetcar Named Desire, A (1951)', 'Cool Hand Luke (1967)', 'Lawrence of Arabia (1962)']
#
#
# Recommendations for User 598: ['Streetcar Named Desire, A (1951)', 'Lawrence of Arabia (1962)', 'Whiplash (2014)', 'Femme Nikita, La (Nikita) (1990)', 'Maltese Falcon, The (1941)']
#
#
# Recommendations for User 358: ["Guess Who's Coming to Dinner (1967)", 'Lawrence of Arabia (1962)', 'Finding Nemo (2003)', 'Double Indemnity (1944)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)']
#
#
# Recommendations for User 578: ['Lawrence of Arabia (1962)', 'American History X (1998)', 'Shawshank Redemption, The (1994)', 'Life Is Beautiful (La Vita è bella) (1997)', 'In the Name of the Father (1993)']
#
#
# Recommendations for User 496: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Lawrence of Arabia (1962)', 'Glory (1989)', 'Cinema Paradiso (Nuovo cinema Paradiso) (1989)']
#
#
# Recommendations for User 481: ['Shawshank Redemption, The (1994)', 'Life Is Beautiful (La Vita è bella) (1997)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Sound of Music, The (1965)']
#
#
# Recommendations for User 320: ['Lawrence of Arabia (1962)', 'Shawshank Redemption, The (1994)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Dark Knight Rises, The (2012)']
#
#
# Recommendations for User 236: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', "Schindler's List (1993)", 'Shawshank Redemption, The (1994)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
#
#
# Recommendations for User 306: ['Casablanca (1942)', 'Usual Suspects, The (1995)', 'Streetcar Named Desire, A (1951)', 'Rear Window (1954)', 'Maltese Falcon, The (1941)']
#
#
# Recommendations for User 163: ['Princess Bride, The (1987)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)', 'Evil Dead II (Dead by Dawn) (1987)', 'Whiplash (2014)', 'Spotlight (2015)']
#
#
# Recommendations for User 360: ['Lawrence of Arabia (1962)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Lord of the Rings: The Return of the King, The (2003)', "It's a Wonderful Life (1946)", 'Godfather, The (1972)']
#
#
# Recommendations for User 535: ['In the Name of the Father (1993)', 'Hoop Dreams (1994)', "Rosemary's Baby (1968)", 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)']
#
#
# Recommendations for User 184: ['There Will Be Blood (2007)', 'Shawshank Redemption, The (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'South Park: Bigger, Longer and Uncut (1999)']

# %% [markdown]
# ### K-NN with similarity measures

# %%
sim_options = {'name': 'pearson_baseline',
               'user_based': False  # compute  similarities between items
               }

algo_knn = KNNBaseline(sim_options=sim_options)
algo_knn.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
movie = 'Jumanji (1995)'

# Retrieve inner id of the movie Toy Story
movie_raw_id = title_to_id_map[movie]
movie_inner_id = algo_knn.trainset.to_inner_iid(movie_raw_id)

# Retrieve inner ids of the nearest neighbors of Toy Story.
movie_neighbors = algo_knn.get_neighbors(movie_inner_id, k=10)

# Convert inner ids of the neighbors into names.
movie_neighbors = (algo_knn.trainset.to_raw_iid(inner_id)
                       for inner_id in movie_neighbors)
movie_neighbors = (id_to_title_map[rid]
                       for rid in movie_neighbors)

print()
print(f'The 10 nearest neighbors of {movie} are:\n')
for movie in movie_neighbors:
    print(movie)
# Out:
# The 10 nearest neighbors of Jumanji (1995) are:
#
# Mrs. Doubtfire (1993)
# Mask, The (1994)
# Back to the Future (1985)
# Liar Liar (1997)
# True Lies (1994)
# Casper (1995)
# Back to the Future Part III (1990)
# Santa Clause, The (1994)
# Prestige, The (2006)
# Babe (1995)

# %% [markdown]
# ### AWS Personalize

# %%
## data format for dumping into AWS S3

ratings = shuffle(ratings_df)
ratings = ratings[ratings['rating']>3.6]
ratings = ratings.drop(columns='rating')
ratings.columns = ['USER_ID','ITEM_ID','TIMESTAMP']
ratings = ratings[:100000]
#ratings.to_csv('ratings.processed.csv',index=False)

# %%
one_movie_user = ratings.drop_duplicates(subset="USER_ID").drop('TIMESTAMP', axis=1).reset_index(drop=True)
one_movie_user_df = one_movie_user.merge(movies_df, right_on='movieId', left_on='ITEM_ID').drop('movieId', axis=1)
one_movie_user_df.head(25)
# Out:
#     USER_ID  ITEM_ID                                              title  \
# 0        69     1721                                     Titanic (1997)
# 1       593       50                         Usual Suspects, The (1995)
# 2       510       50                         Usual Suspects, The (1995)
# 3       424     4450                                       Bully (2001)
# 4       602      357                 Four Weddings and a Funeral (1994)
# 5       372      357                 Four Weddings and a Funeral (1994)
# 6       443      608                                       Fargo (1996)
# 7       220      608                                       Fargo (1996)
# 8       302      608                                       Fargo (1996)
# 9       120      608                                       Fargo (1996)
# 10      119    64614                                 Gran Torino (2008)
# 11      448     1283                                   High Noon (1952)
# 12      254      590                          Dances with Wolves (1990)
# 13      530      590                          Dances with Wolves (1990)
# 14       15     5989                         Catch Me If You Can (2002)
# 15       63     5989                         Catch Me If You Can (2002)
# 16      258     5989                         Catch Me If You Can (2002)
# 17       43      208                                  Waterworld (1995)
# 18      240      208                                  Waterworld (1995)
# 19      499     2337                             Velvet Goldmine (1998)
# 20      381    30749                                Hotel Rwanda (2004)
# 21      178    30749                                Hotel Rwanda (2004)
# 22      474     8983   House of Flying Daggers (Shi mian mai fu) (2004)
# 23      339     5618  Spirited Away (Sen to Chihiro no kamikakushi) ...
# 24      459     5618  Spirited Away (Sen to Chihiro no kamikakushi) ...
#
#                          genres
# 0                 Drama|Romance
# 1        Crime|Mystery|Thriller
# 2        Crime|Mystery|Thriller
# 3          Crime|Drama|Thriller
# 4                Comedy|Romance
# 5                Comedy|Romance
# 6   Comedy|Crime|Drama|Thriller
# 7   Comedy|Crime|Drama|Thriller
# 8   Comedy|Crime|Drama|Thriller
# 9   Comedy|Crime|Drama|Thriller
# 10                  Crime|Drama
# 11                Drama|Western
# 12      Adventure|Drama|Western
# 13      Adventure|Drama|Western
# 14                  Crime|Drama
# 15                  Crime|Drama
# 16                  Crime|Drama
# 17      Action|Adventure|Sci-Fi
# 18      Action|Adventure|Sci-Fi
# 19                        Drama
# 20                    Drama|War
# 21                    Drama|War
# 22         Action|Drama|Romance
# 23  Adventure|Animation|Fantasy
# 24  Adventure|Animation|Fantasy

# %% [markdown]
# #### AWS results using AutoML - HRNN

# %%
idx = 19

campaign_arn = "arn:aws:personalize:us-east-1:376337229415:campaign/aws-automl"
user_id, item_id = one_movie_user_df.iloc[idx, :2]
personalize = boto3.client(service_name='personalize', endpoint_url='https://personalize.us-east-1.amazonaws.com')
personalize_runtime = boto3.client(service_name='personalize-runtime', endpoint_url='https://personalize-runtime.us-east-1.amazonaws.com')
get_recommendations_response = personalize_runtime.get_recommendations(
    campaignArn = campaign_arn,
    userId = str(user_id),
    itemId = str(item_id)
)

item_list = get_recommendations_response['itemList']

user_movie = id_to_title_map[item_id]
print(f"For user {user_id} who likes '{user_movie}', we can recommend:\n")

for item in item_list:
    print(id_to_title_map[int(item['itemId'])])
# Out:
# For user 499 who likes 'Velvet Goldmine (1998)', we can recommend:
#
# Training Day (2001)
# Bill & Ted's Excellent Adventure (1989)
# 2001: A Space Odyssey (1968)
# Schindler's List (1993)
# Airplane! (1980)
# Pleasantville (1998)
# Naked Gun: From the Files of Police Squad!, The (1988)
# Mary Poppins (1964)
# Princess Bride, The (1987)
# Signs (2002)
# Pi (1998)
# Big Trouble in Little China (1986)
# Blade Runner (1982)
# Illusionist, The (2006)
# Office Space (1999)
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# High Fidelity (2000)
# Escape from New York (1981)
# Austin Powers: International Man of Mystery (1997)
# Rushmore (1998)
# Usual Suspects, The (1995)
# Close Encounters of the Third Kind (1977)
# Rounders (1998)
# Ocean's Eleven (2001)
# Collateral (2004)
